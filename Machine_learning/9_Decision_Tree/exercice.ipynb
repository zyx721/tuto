# %%
import pandas as pd

# %%
df = pd.read_csv("titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop(["PassengerId","SibSp","Name","Parch","Cabin","Ticket","Embarked"],axis='columns',inplace=True)

# %%
df
# Out:
#      Survived  Pclass     Sex   Age     Fare
# 0           0       3    male  22.0   7.2500
# 1           1       1  female  38.0  71.2833
# 2           1       3  female  26.0   7.9250
# 3           1       1  female  35.0  53.1000
# 4           0       3    male  35.0   8.0500
# ..        ...     ...     ...   ...      ...
# 886         0       2    male  27.0  13.0000
# 887         1       1  female  19.0  30.0000
# 888         0       3  female   NaN  23.4500
# 889         1       1    male  26.0  30.0000
# 890         0       3    male  32.0   7.7500
#
# [891 rows x 5 columns]

# %%
inp = df.drop(['Survived'],axis='columns')

# %%
tar = df.Survived

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tar
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
inp
# Out:
#      Pclass     Sex   Age     Fare
# 0         3    male  22.0   7.2500
# 1         1  female  38.0  71.2833
# 2         3  female  26.0   7.9250
# 3         1  female  35.0  53.1000
# 4         3    male  35.0   8.0500
# ..      ...     ...   ...      ...
# 886       2    male  27.0  13.0000
# 887       1  female  19.0  30.0000
# 888       3  female  28.0  23.4500
# 889       1    male  26.0  30.0000
# 890       3    male  32.0   7.7500
#
# [891 rows x 4 columns]

# %%
inp.Age.median()
# Out:
# np.float64(28.0)

# %%
inp['Age'].fillna(inp.Age.median(),inplace=True)

# %%
inp[inp.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Pclass, Sex, Age, Fare]
# Index: []

# %%
inp.isna().sum()
# Out:
# Pclass    0
# Sex       0
# Age       0
# Fare      0
# dtype: int64

# %%
inp['Sex'] = inp['Sex'].apply(lambda x : 0 if x == 'male' else 1)

# %%
 from sklearn import tree

# %%
model = tree.DecisionTreeClassifier()

# %%
from sklearn.model_selection import train_test_split

# %%
tr1,ts1,tr2,ts2 = train_test_split(inp,tar,test_size=0.3)

# %%
import numpy as np
X_array = tr1.values
y_array = tr2.values

# %%
model.fit(tr1,tr2)
# Out:
# DecisionTreeClassifier()

# %%
model.score(ts1,ts2)
# Out:
# 0.832089552238806
